# %%
import numpy as np
import pandas as pd

import os
for dirname, _,filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        os.path.join(dirname, filename)

# %%
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, save_img

from collections import Counter

import numpy as np

import os

import shutil

from sklearn.utils import resample

from tensorflow.keras.utils import image_dataset_from_directory

from sklearn.metrics import classification_report, confusion_matrix

import matplotlib.pyplot as plt

import seaborn as sns

# %%
dataset_path = "/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group"

# %%
BATCH_SIZE=32

# %%
#Step 1: Load dataset

dataset = image_dataset_from_directory(
    dataset_path,
    labels = "inferred",
    label_mode="int",
    image_size=(64, 64), # Resize images to a standard size
    batch_size=BATCH_SIZE,
    shuffle=True
)
# Out:
# Found 6000 files belonging to 8 classes.

# %%
# Step 2: Check class distribution

class_names = dataset.class_names
class_counts = Counter()

for _, labels in dataset.unbatch():
    class_counts[int(labels.numpy())] += 1

print("Class Distribution:")

for i, count in class_counts.items():
    print(f"{class_names[i]}: {count}")
# Out:
# Class Distribution:
# O+: 852
# AB+: 708
# A-: 1009
# O-: 712
# AB-: 761
# B+: 652
# A+: 565
# B-: 741

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Function to plot class distribution
def plot_class_distribution(class_names, class_counts):
    """
    Plots the distribution of classes in the dataset.

    Parameters:
    - class_names (list): List of class names.
    - class_counts (dict): Dictionary with class indices as keys and counts as values.
    
    Returns:
    - None
    """
    # Extract class names and their corresponding counts
    classes = [class_names[i] for i in class_counts.keys()]
    counts = [class_counts[i] for i in class_counts.keys()]

    # Plot the bar chart
    plt.figure(figsize=(10, 6))
    plt.bar(classes, counts, color='skyblue')
    plt.xlabel('Class')
    plt.ylabel('Count')
    plt.title('Class Distribution in Dataset')
    plt.xticks(rotation=45)
    plt.show()

# Initialize Counter
class_counts = Counter()

# Count the occurrences of each class
for image, label in dataset.unbatch():  # `dataset.unbatch()` yields (image, label) pairs
    class_counts[int(label.numpy())] += 1  # Convert label tensor to integer and count occurrences

# Get class names from dataset
class_names = dataset.class_names

# %%
# Call the function to plot the distribution
plot_class_distribution(class_names, class_counts)

# %%
max_count = max(class_counts.values())

# %%
#Function to oversample a class
def oversample_class(class_id, count, max_count):
    #Ensure the dataset is unbatched for filtering
    unbatched_dataset = dataset.unbatch()
    
    #Filter the dataset for the specific class
    class_dataset = unbatched_dataset.filter(lambda img, lbl: tf.equal(lbl, class_id))
    
    #Calculate the number of repetitions needed
    repeat_factor = max_count // count + (max_count% count > 0)
    
    #Repeat the dataset to match the desired count
    return class_dataset.repeat(repeat_factor).take(max_count)

# %%
#Step 1: Balance the dataset
balanced_datasets = []
for class_id, count in class_counts.items():
    balanced_datasets.append(oversample_class(class_id, count, max_count))

#Step 2: Combine balanced datasets
balanced_dataset = tf.data.Dataset.sample_from_datasets (balanced_datasets)

#Step 3: Check balanced class distribution
balanced_class_counts = Counter([int(lbl.numpy()) for _, lbl in balanced_dataset])
plot_class_distribution(class_names, balanced_class_counts)

#Step 4: Batch the balanced dataset
balanced_dataset = balanced_dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
for sample in balanced_dataset.take(10):
    print(sample[0].shape)
# Out:
# (32, 64, 64, 3)
# (32, 64, 64, 3)
# (32, 64, 64, 3)
# (32, 64, 64, 3)
# (32, 64, 64, 3)
# (32, 64, 64, 3)
# (32, 64, 64, 3)
# (32, 64, 64, 3)
# (32, 64, 64, 3)
# (32, 64, 64, 3)

# %%
balanced_dataset_unbatched = balanced_dataset.unbatch()
dataset_size = sum(1 for _ in balanced_dataset_unbatched)
print(f"Total dataset size: {dataset_size}")
# Out:
# Total dataset size: 8064

# %%
train_ratio = 0.7
val_ratio = 0.2

# %%
#Unbatch the dataset to work at the sample level
balanced_dataset_unbatched = balanced_dataset.unbatch()

#Compute sizes based on dataset size and desired splits
train_size = int(train_ratio * dataset_size)
val_size = int(val_ratio * dataset_size)

#Split the dataset into training, validation, and test
train_dataset = balanced_dataset_unbatched.take(train_size)
val_test_dataset = balanced_dataset_unbatched.skip(train_size)
val_dataset = val_test_dataset.take(val_size)
test_dataset =val_test_dataset.skip(val_size)

#Rebatch the datasets after splitting
train_dataset= train_dataset.batch(BATCH_SIZE, drop_remainder =True)
val_dataset= val_dataset.batch(BATCH_SIZE, drop_remainder = True)
test_dataset= test_dataset.batch(BATCH_SIZE, drop_remainder = True)

# Check the number of batches in each dataset
train_batch_count = sum(1 for _ in train_dataset)
val_batch_count = sum(1 for _ in val_dataset)
test_batch_count = sum (1 for _ in test_dataset)



print(f"Training dataset size: {train_batch_count * BATCH_SIZE}")
print(f"Validation dataset size: {val_batch_count * BATCH_SIZE}")
print(f"testing dataset size: {test_batch_count * BATCH_SIZE}")
# Out:
# Training dataset size: 5632
# Validation dataset size: 1600
# testing dataset size: 800

# %%
def create_high_accuracy_model():
    model = tf.keras.models.Sequential ([
    
        tf.keras.layers.Conv2D(32, (3, 3), activations ='relu', padding ='same', input_shape=(64, 64, 3)),
        tf.karas.Layers.MaxPooling2D(2, 2),
        tf.keras.Layers.Dropout(0.3),
        
        tf.karas.layers.Conv2D(64, (3, 3), activations='relu', padding='same'),
        tf.karas.layers.MaxPooling2D(2, 2),
        tf.kerss.layers.Dropout(0.4),
        
        
        
        tf.karas.layers.Conv2D (128, (3, 3), activatione='relu', padding='same'),
        tf.karas.layers.MaxPooling2D(2,2),
        tf.karss.layers.Dropout(0.4),
        
        
        tf.karas.layers.Conv2D(256, (3, 3), activations='relu', padding='same'),
        tf.karas.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Dropout(0.4),
        
        tf.keras.layers.Conv2D(512, (3, 3), activations ='relu', pedding ='same'),
        tf.karas.layers.MaxPooling2D(2, 2),
        tf.karas.layers.Dropout (0.5),

        tf.keras.layers.Flattan(),
        tf.keras.layers.Dense(1024, activations='relu'),
        tf.keras.layers.Dropout(0.5),
                               
        tf.keras.layers.Dense(len(class_names), activation='softmax')
    ])
    model.compile(optimizern='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model




#Create the model
high_acc_model = create_high_accuracy_model()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-5adba35007c9> in <cell line: 42>()
#      40
#      41 #Create the model
# ---> 42 high_acc_model = create_high_accuracy_model()
#
# <ipython-input-42-5adba35007c9> in create_high_accuracy_model()
#       2     model = tf.keras.models.Sequential ([
#       3
# ----> 4         tf.keras.layers.Conv2D(32, (3, 3), activations ='relu', padding ='same', input_shape=(64, 64, 3)),
#       5         tf.karas.Layers.MaxPooling2D(2, 2),
#       6         tf.keras.Layers.Dropout(0.3),
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/conv2d.py in __init__(self, filters, kernel_size, strides, padding, data_format, dilation_rate, groups, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     107         **kwargs
#     108     ):
# --> 109         super().__init__(
#     110             rank=2,
#     111             filters=filters,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py in __init__(self, rank, filters, kernel_size, strides, padding, data_format, dilation_rate, groups, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, lora_rank, **kwargs)
#     105         **kwargs,
#     106     ):
# --> 107         super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#     108         self.rank = rank
#     109         self.filters = filters
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py in __init__(self, activity_regularizer, trainable, dtype, autocast, name, **kwargs)
#     283             self._input_shape_arg = input_shape_arg
#     284         if kwargs:
# --> 285             raise ValueError(
#     286                 "Unrecognized keyword arguments "
#     287                 f"passed to {self.__class__.__name__}: {kwargs}"
#
# ValueError: Unrecognized keyword arguments passed to Conv2D: {'activations': 'relu'}

# %%
def create_high_accuracy_model():
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(64, 64, 3)),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Dropout(0.3),

        tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Dropout(0.4),

        tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Dropout(0.4),

        tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Dropout(0.4),

        tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Dropout(0.5),

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(1024, activation='relu'),
        tf.keras.layers.Dropout(0.5),

        tf.keras.layers.Dense(len(class_names), activation='softmax')
    ])
    
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Create the model
high_acc_model = create_high_accuracy_model()

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

#Define ReduceLROnPlateau callback to reduce learning rate when validation less plateaus
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    verbose =1,
    min_lr=1e-6,
)

#Define EarlyStopping callback to stop training when validation loss doesn't improve
early_stop = EarlyStopping(
    monitor='val_loss',              #Monitor validation loss
    patience=5,                        #Stop after 5 epochs without Improvement
    verbose =1,
    restore_best_weights=True,         #Restore the model weights from the best epoch
)

# %%
#Train the model

history_high_acc = high_acc_model.fit(
    train_dataset, 
    validation_data=val_dataset,
    epochs= 50, #Adjust the number of epochs based on your preference
    callbacks = [reduce_lr, early_stop]
)
# Out:
# Epoch 1/50
#     176/Unknown 66s 353ms/step - accuracy: 0.1250 - loss: 30.2939
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 83s 455ms/step - accuracy: 0.1250 - loss: 30.1708 - val_accuracy: 0.1268 - val_loss: 2.0377 - learning_rate: 0.0010
# Epoch 2/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 80s 452ms/step - accuracy: 0.1348 - loss: 2.0798 - val_accuracy: 0.2065 - val_loss: 2.0196 - learning_rate: 0.0010
# Epoch 3/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 80s 451ms/step - accuracy: 0.2067 - loss: 1.9842 - val_accuracy: 0.3652 - val_loss: 1.7575 - learning_rate: 0.0010
# Epoch 4/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 81s 462ms/step - accuracy: 0.4479 - loss: 1.4756 - val_accuracy: 0.6483 - val_loss: 1.2287 - learning_rate: 0.0010
# Epoch 5/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 80s 454ms/step - accuracy: 0.5666 - loss: 1.1586 - val_accuracy: 0.6115 - val_loss: 1.1600 - learning_rate: 0.0010
# Epoch 6/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 81s 456ms/step - accuracy: 0.6393 - loss: 0.9941 - val_accuracy: 0.6109 - val_loss: 1.2673 - learning_rate: 0.0010
# Epoch 7/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 83s 468ms/step - accuracy: 0.6442 - loss: 0.9878 - val_accuracy: 0.7555 - val_loss: 0.8438 - learning_rate: 0.0010
# Epoch 8/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 77s 437ms/step - accuracy: 0.6901 - loss: 0.8492 - val_accuracy: 0.7672 - val_loss: 0.8710 - learning_rate: 0.0010
# Epoch 9/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 78s 444ms/step - accuracy: 0.7254 - loss: 0.7788 - val_accuracy: 0.7169 - val_loss: 0.9323 - learning_rate: 0.0010
# Epoch 10/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.7286 - loss: 0.7420
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 79s 447ms/step - accuracy: 0.7286 - loss: 0.7420 - val_accuracy: 0.6201 - val_loss: 1.0917 - learning_rate: 0.0010
# Epoch 11/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 77s 438ms/step - accuracy: 0.7478 - loss: 0.6777 - val_accuracy: 0.8211 - val_loss: 0.7036 - learning_rate: 5.0000e-04
# Epoch 12/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 78s 442ms/step - accuracy: 0.7801 - loss: 0.5972 - val_accuracy: 0.7065 - val_loss: 0.9125 - learning_rate: 5.0000e-04
# Epoch 13/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 77s 437ms/step - accuracy: 0.7754 - loss: 0.5921 - val_accuracy: 0.8009 - val_loss: 0.6964 - learning_rate: 5.0000e-04
# Epoch 14/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 79s 446ms/step - accuracy: 0.7962 - loss: 0.5500 - val_accuracy: 0.8051 - val_loss: 0.6428 - learning_rate: 5.0000e-04
# Epoch 15/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 78s 444ms/step - accuracy: 0.7840 - loss: 0.5924 - val_accuracy: 0.6513 - val_loss: 1.0389 - learning_rate: 5.0000e-04
# Epoch 16/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 78s 443ms/step - accuracy: 0.8040 - loss: 0.5454 - val_accuracy: 0.8021 - val_loss: 0.7061 - learning_rate: 5.0000e-04
# Epoch 17/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 78s 443ms/step - accuracy: 0.8040 - loss: 0.5114 - val_accuracy: 0.8321 - val_loss: 0.6121 - learning_rate: 5.0000e-04
# Epoch 18/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 77s 438ms/step - accuracy: 0.7994 - loss: 0.5110 - val_accuracy: 0.6262 - val_loss: 1.0209 - learning_rate: 5.0000e-04
# Epoch 19/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 75s 425ms/step - accuracy: 0.8125 - loss: 0.5167 - val_accuracy: 0.8554 - val_loss: 0.4951 - learning_rate: 5.0000e-04
# Epoch 20/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 75s 422ms/step - accuracy: 0.8072 - loss: 0.5165 - val_accuracy: 0.8125 - val_loss: 0.5638 - learning_rate: 5.0000e-04
# Epoch 21/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 75s 423ms/step - accuracy: 0.8083 - loss: 0.5160 - val_accuracy: 0.8517 - val_loss: 0.4684 - learning_rate: 5.0000e-04
# Epoch 22/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 74s 420ms/step - accuracy: 0.8164 - loss: 0.4852 - val_accuracy: 0.8664 - val_loss: 0.4988 - learning_rate: 5.0000e-04
# Epoch 23/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 74s 422ms/step - accuracy: 0.8162 - loss: 0.4741 - val_accuracy: 0.7586 - val_loss: 0.7270 - learning_rate: 5.0000e-04
# Epoch 24/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.8086 - loss: 0.4959
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 75s 423ms/step - accuracy: 0.8086 - loss: 0.4959 - val_accuracy: 0.8487 - val_loss: 0.4914 - learning_rate: 5.0000e-04
# Epoch 25/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 75s 424ms/step - accuracy: 0.8383 - loss: 0.4271 - val_accuracy: 0.8315 - val_loss: 0.5358 - learning_rate: 2.5000e-04
# Epoch 26/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 74s 420ms/step - accuracy: 0.8382 - loss: 0.4033 - val_accuracy: 0.8756 - val_loss: 0.4375 - learning_rate: 2.5000e-04
# Epoch 27/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 74s 416ms/step - accuracy: 0.8505 - loss: 0.3917 - val_accuracy: 0.8591 - val_loss: 0.4571 - learning_rate: 2.5000e-04
# Epoch 28/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 74s 417ms/step - accuracy: 0.8464 - loss: 0.4002 - val_accuracy: 0.7739 - val_loss: 0.6588 - learning_rate: 2.5000e-04
# Epoch 29/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.8532 - loss: 0.3981
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 73s 415ms/step - accuracy: 0.8531 - loss: 0.3980 - val_accuracy: 0.8462 - val_loss: 0.4702 - learning_rate: 2.5000e-04
# Epoch 30/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 73s 415ms/step - accuracy: 0.8447 - loss: 0.3902 - val_accuracy: 0.8652 - val_loss: 0.4321 - learning_rate: 1.2500e-04
# Epoch 31/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 74s 418ms/step - accuracy: 0.8561 - loss: 0.3751 - val_accuracy: 0.8873 - val_loss: 0.3620 - learning_rate: 1.2500e-04
# Epoch 32/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 74s 419ms/step - accuracy: 0.8642 - loss: 0.3573 - val_accuracy: 0.8866 - val_loss: 0.3786 - learning_rate: 1.2500e-04
# Epoch 33/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 75s 424ms/step - accuracy: 0.8498 - loss: 0.3650 - val_accuracy: 0.8909 - val_loss: 0.3513 - learning_rate: 1.2500e-04
# Epoch 34/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 74s 420ms/step - accuracy: 0.8775 - loss: 0.3339 - val_accuracy: 0.8382 - val_loss: 0.4556 - learning_rate: 1.2500e-04
# Epoch 35/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 75s 422ms/step - accuracy: 0.8628 - loss: 0.3487 - val_accuracy: 0.8756 - val_loss: 0.3766 - learning_rate: 1.2500e-04
# Epoch 36/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.8649 - loss: 0.3386
# Epoch 36: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 75s 426ms/step - accuracy: 0.8648 - loss: 0.3387 - val_accuracy: 0.8940 - val_loss: 0.3525 - learning_rate: 1.2500e-04
# Epoch 37/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 75s 425ms/step - accuracy: 0.8726 - loss: 0.3365 - val_accuracy: 0.8848 - val_loss: 0.3667 - learning_rate: 6.2500e-05
# Epoch 38/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 75s 427ms/step - accuracy: 0.8730 - loss: 0.3295 - val_accuracy: 0.9001 - val_loss: 0.3400 - learning_rate: 6.2500e-05
# Epoch 39/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 76s 433ms/step - accuracy: 0.8770 - loss: 0.3202 - val_accuracy: 0.8836 - val_loss: 0.3507 - learning_rate: 6.2500e-05
# Epoch 40/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 76s 431ms/step - accuracy: 0.8752 - loss: 0.3250 - val_accuracy: 0.8836 - val_loss: 0.3564 - learning_rate: 6.2500e-05
# Epoch 41/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.8754 - loss: 0.3269
# Epoch 41: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 76s 431ms/step - accuracy: 0.8754 - loss: 0.3269 - val_accuracy: 0.8952 - val_loss: 0.3451 - learning_rate: 6.2500e-05
# Epoch 42/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 77s 434ms/step - accuracy: 0.8738 - loss: 0.3209 - val_accuracy: 0.8971 - val_loss: 0.3289 - learning_rate: 3.1250e-05
# Epoch 43/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 74s 420ms/step - accuracy: 0.8742 - loss: 0.3258 - val_accuracy: 0.8934 - val_loss: 0.3345 - learning_rate: 3.1250e-05
# Epoch 44/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 75s 425ms/step - accuracy: 0.8901 - loss: 0.2937 - val_accuracy: 0.8897 - val_loss: 0.3296 - learning_rate: 3.1250e-05
# Epoch 45/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.8878 - loss: 0.3063
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 77s 435ms/step - accuracy: 0.8877 - loss: 0.3063 - val_accuracy: 0.8995 - val_loss: 0.3302 - learning_rate: 3.1250e-05
# Epoch 46/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 74s 421ms/step - accuracy: 0.8837 - loss: 0.3055 - val_accuracy: 0.8934 - val_loss: 0.3346 - learning_rate: 1.5625e-05
# Epoch 47/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 74s 421ms/step - accuracy: 0.8831 - loss: 0.3017 - val_accuracy: 0.8971 - val_loss: 0.3254 - learning_rate: 1.5625e-05
# Epoch 48/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 75s 422ms/step - accuracy: 0.8868 - loss: 0.3073 - val_accuracy: 0.9044 - val_loss: 0.3138 - learning_rate: 1.5625e-05
# Epoch 49/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 76s 431ms/step - accuracy: 0.8886 - loss: 0.2838 - val_accuracy: 0.8946 - val_loss: 0.3251 - learning_rate: 1.5625e-05
# Epoch 50/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 75s 423ms/step - accuracy: 0.8906 - loss: 0.2934 - val_accuracy: 0.9093 - val_loss: 0.3129 - learning_rate: 1.5625e-05
# Restoring model weights from the end of the best epoch: 50.

# %%
#Evaluate the model on validation data 

high_acc_eval= high_acc_model.evaluate(val_dataset)
print(f"High Accuracy Model Loss: {high_acc_eval[0]}, Accuracy: {high_acc_eval[1]}")
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step - accuracy: 0.9299 - loss: 0.3130
# High Accuracy Model Loss: 0.31493157148361206, Accuracy: 0.908088207244873

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
def plot_accuracy(history):

    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

#Call the function to display the accuracy graph
plot_accuracy(history_high_acc)

# %%
#Get predictions on the test dataset

y_true = [] #True labels

y_pred = [] #Predicted labels

# Iterate over the test dataset and collect the true and predicted labels
for inages, labels in test_dataset:

    predictions = high_acc_model.predict(images)
    
    predicted_labels = np.argmax(predictions, axis-1) 
    y_true.extend(labels.numpy()) # Convert tensor to ropy array and append
    y_pred.extend(predicted_labels)     #Append the predicted labels


#Convert to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)


#Classification report
report = classification_report(y_true, y_pred, target_names=class_names)
print("Classification Report:")
print(report)


#Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

#Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot = True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-58fa381c34ab> in <cell line: 8>()
#       8 for inages, labels in test_dataset:
#       9
# ---> 10     predictions = high_acc_model.predict(images)
#      11
#      12     predicted_labels = np.argmax(predictions, axis-1)
#
# NameError: name 'images' is not defined

# %%
##Up Fix

# Get predictions on the test dataset

y_true = []  # True labels
y_pred = []  # Predicted labels

# Iterate over the test dataset and collect the true and predicted labels
for images, labels in test_dataset:  # Fixed typo (inages → images)

    predictions = high_acc_model.predict(images)

    predicted_labels = np.argmax(predictions, axis=1)  # Fixed axis-1 → axis=1
    y_true.extend(labels.numpy())  # Convert tensor to numpy array and append
    y_pred.extend(predicted_labels)  # Append the predicted labels

# Convert to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Classification report
report = classification_report(y_true, y_pred, target_names=class_names)
print("Classification Report:")
print(report)

# Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#           A+       0.98      0.93      0.95       111
#           A-       0.82      0.88      0.85        73
#          AB+       0.92      0.94      0.93        95
#          AB-       0.96      0.89      0.92       114
#           B+       0.99      0.94      0.97       118
#           B-       0.86      1.00      0.92       107
#           O+       0.89      0.94      0.91        77
#           O-       0.95      0.88      0.91       105
#
#     accuracy                           0.92       800
#    macro avg       0.92      0.92      0.92       800
# weighted avg       0.93      0.92      0.92       800

# %%
# Get predictions on the test dataset
y_true = []  # True labels
y_pred = []  # Predicted labels

# Iterate over the test dataset and collect the true and predicted labels
for images, labels in test_dataset:
    predictions = high_acc_model.predict(images)
    predicted_labels = np.argmax(predictions, axis=1)  
    y_true.extend(labels.numpy())  
    y_pred.extend(predicted_labels)  

# Convert to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Generate classification report
report = classification_report(y_true, y_pred, output_dict=True)
print("Classification Report:")
print(classification_report(y_true, y_pred))

# Extract overall metrics
accuracy = report['accuracy']
precision = report['macro avg']['precision']
recall = report['macro avg']['recall']
f1_score = report['macro avg']['f1-score']

# Metrics list for plotting
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
values = [accuracy, precision, recall, f1_score]

# Plot overall performance
plt.figure(figsize=(6, 4))
plt.bar(metrics, values, color='skyblue')

plt.ylim(0, 1)
plt.ylabel('Score')
plt.title('Overall Model Performance')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display the values on top of the bars
for i, v in enumerate(values):
    plt.text(i, v + 0.02, f"{v:.2f}", ha='center', fontsize=12)

plt.show()

# %%
high_acc_model.save('model.h5') # The model will be saved as 'my model.h5'
print("Model saved as HDF5 format.")
# Out:
# Model saved as HDF5 format.

# %%
pip show pillow
# Out:
# Name: pillow
# Version: 11.0.0
# Summary: Python Imaging Library (Fork)
# Home-page: https://python-pillow.org
# Author:
# Author-email: "Jeffrey A. Clark" <aclark@aclark.net>
# License: MIT-CMU
# Location: /usr/local/lib/python3.10/dist-packages
# Requires:
# Required-by: bokeh, datashader, diffusers, dopamine_rl, easyocr, fastai, fury, google-genai, ImageHash, imageio, imgaug, ipympl, matplotlib, openslide-python, pdf2image, pytesseract, scikit-image, sentence-transformers, torchtune, torchvision, wordcloud
# Note: you may need to restart the kernel to use updated packages.
